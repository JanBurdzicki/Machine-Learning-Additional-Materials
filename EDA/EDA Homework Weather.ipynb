# %% [markdown]
# ## Open the data

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os, sys

# %%
data_directory = '~/Downloads/weather.csv'
os.path.isfile(data_directory)
# Out:
# False

# %%
# url = 'https://drive.google.com/file/d/1Tc7GeVN7DLEl-RAs-JVwG9yFMf--S8dy/edit' # doesn't work, TBD
# TODO: export data to fast file format
data = pd.read_csv(data_directory, low_memory=False)

# %% [markdown]
# ## Faster reading data (file formats)
#
# [Link to complex article](
# https://towardsdatascience.com/guide-to-file-formats-for-machine-learning-columnar-training-inferencing-and-the-feature-store-2e0c3d18d4f9)
#
# Most interesting formats:
# * Parquet (Spark)
# * ORC (Spark)
# * petastorm (Tenserflow, PyTorch)
# * avro

# %% [markdown]
# ## Importing and exporting (reading ?!) -> TBA

# %%
display(data.info)
# Out:
# <bound method DataFrame.info of                       date  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0      2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 1      2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2      2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 3      2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 4      2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
# ...                    ...       ...       ...       ...          ...     ...
# 52691  2020-12-31 23:20:00    978.32      2.28    277.16        -0.80    80.0
# 52692  2020-12-31 23:30:00    978.30      2.13    277.01        -0.43    83.1
# 52693  2020-12-31 23:40:00    978.26      1.99    276.88        -0.71    82.2
# 52694  2020-12-31 23:50:00    978.26      2.07    276.95        -0.77    81.4
# 52695  2021-01-01 00:00:00    978.24      2.01    276.89        -0.66    82.4
#
# ...

# %%
data.head(15)
# Out:
#                    date  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0   2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 1   2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2   2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 3   2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 4   2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
# 5   2020-01-01 01:00:00   1008.44      0.34    272.84        -1.54    87.1
# 6   2020-01-01 01:10:00   1008.49      0.19    272.69        -1.65    87.4
# 7   2020-01-01 01:20:00   1008.40      0.03    272.53        -1.70    88.1
# 8   2020-01-01 01:30:00   1008.29      0.11    272.63        -1.61    88.1
# 9   2020-01-01 01:40:00   1008.28      0.22    272.73        -1.62    87.4
# 10  2020-01-01 01:50:00   1008.24     -0.04    272.48        -1.85    87.5
# ...

# %% [markdown]
# ## Define task (TBA)
#
# Task: Weather forecast for the next day/week/month

# %% [markdown]
# ## Data types - analyse and fix

# %%
data.columns
# Out:
# Index(['date', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)', 'rh (%)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)', 'rain (mm)', 'raining (s)', 'SWDR (W/m�)',
#        'PAR (�mol/m�/s)', 'max. PAR (�mol/m�/s)', 'Tlog (degC)', 'OT'],
#       dtype='object')

# %%
for column in data.columns:
    print(f"{column}: {data[column].dtype}")
# Out:
# date: datetime64[ns]
# p (mbar): float64
# T (degC): float64
# Tpot (K): float64
# Tdew (degC): float64
# rh (%): float64
# VPmax (mbar): float64
# VPact (mbar): float64
# VPdef (mbar): float64
# sh (g/kg): float64
# H2OC (mmol/mol): float64
# rho (g/m**3): float64
# wv (m/s): float64
# max. wv (m/s): float64
# wd (deg): float64
# rain (mm): float64
# raining (s): float64
# SWDR (W/m�): float64
# PAR (�mol/m�/s): float64
# max. PAR (�mol/m�/s): float64
# Tlog (degC): float64
# OT: float64

# %% [markdown]
# ## Basic analysis (TBD)
#
# * target distribution
# * empty values (total and per status)
# * variable distribution (total and per status)
# * historical stability (total and per status)
# * *correlation
# * *predictive strength

# %%
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S')
data['date']
# Out:
# 0       2020-01-01 00:10:00
# 1       2020-01-01 00:20:00
# 2       2020-01-01 00:30:00
# 3       2020-01-01 00:40:00
# 4       2020-01-01 00:50:00
#                 ...
# 52691   2020-12-31 23:20:00
# 52692   2020-12-31 23:30:00
# 52693   2020-12-31 23:40:00
# 52694   2020-12-31 23:50:00
# 52695   2021-01-01 00:00:00
# Name: date, Length: 52696, dtype: datetime64[ns]

# %%
# drop_duplicates

# %%
# axis figure out what is what (date for OX axis)
for col in data.columns:
    if data[col].dtype == object:
        if data[col].nunique() > 100:
            print(f"{col} has {data[col].nunique()} unique values -- ommited")
            continue
        data[col].value_counts().plot(kind='bar')
    else:
        data[col].plot(kind='hist')
    plt.title(col)
    plt.show()
# Out:
# date has 52695 unique values -- ommited
